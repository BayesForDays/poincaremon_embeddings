# %%
from gensim.models.poincare import PoincareModel

# %%
import json

# %%
mons = json.load(open('../pokedex.json', 'r'))

# %%
mons['bulbasaur']
# Out:
# {'num': 1,
#  'species': 'Bulbasaur',
#  'types': ['Grass', 'Poison'],
#  'genderRatio': {'M': 0.875, 'F': 0.125},
#  'baseStats': {'hp': 45,
#   'atk': 49,
#   'def': 49,
#   'spa': 65,
#   'spd': 65,
#   'spe': 45},
#  'abilities': {'0': 'Overgrow', 'H': 'Chlorophyll'},
#  'heightm': 0.7,
#  'weightkg': 6.9,
#  'color': 'Green',
#  'evos': ['ivysaur'],
#  'eggGroups': ['Monster', 'Grass']}

# %%
features_to_embed = ['types', 'abilities', 'eggGroups']#, 'evos', 'prevo']
tuples = []
for mon in mons:
    features = mons[mon]
    for feature in features_to_embed:
        if feature not in features:
            t_ = (mon, feature + '_none')
        else:
            if feature=='abilities':
                for ability in features[feature]:
                    t_ = ("mon_" + mon, feature + f"_{features[feature][ability]}")
                    tuples.append(t_)
            elif feature=='types':
                for type_ in features[feature]:
                    t_ = ("mon_" + mon, feature + f"_{type_}")
                    tuples.append(t_)
            elif feature=='eggGroups':
                for eg in features[feature]:
                    t_ = ("mon_" + mon, feature + f"_{eg}")
                    tuples.append(t_)
            elif feature=='evos':
                for evo in features[feature]:
                    t_ = ("mon_" + mon, feature + f"_{evo}")
                    tuples.append(t_)
            elif feature=='prevo':
                t_ = ("mon_" + mon, feature + f"_{features[feature]}")
                tuples.append(t_)

# %%
import pandas as pd
moves_tuples = pd.read_csv("./20191005_mon_moves_features.tsv", sep="\t")

# %%
moves_tuples.head()
# Out:
#          mon       feature_complex feature      feature_val
# 0  bulbasaur      move_sleeppowder    move      sleeppowder
# 1  bulbasaur        move_gigadrain    move        gigadrain
# 2  bulbasaur  move_hiddenpowerfire    move  hiddenpowerfire
# 3  bulbasaur   move_hiddenpowerice    move   hiddenpowerice
# 4  bulbasaur       move_sludgebomb    move       sludgebomb

# %%
tuples += list(zip(['mon_' + x for x in moves_tuples['mon']], ['move_' + x for x in moves_tuples['feature_val']]))

# %%
m = PoincareModel(tuples, negative=2)

# %%
m.train(epochs=50)

# %%
m.kv.similarity('mon_bulbasaur', 'mon_oddish')
# Out:
# 0.1291160586248858

# %%
[x for x in m.kv.most_similar('mon_oddish', 100) if x[0].startswith("mon_")]
# Out:
# [('mon_lurantistotem', 4.830909068069064),
#  ('mon_fomantis', 5.104510225092127),
#  ('mon_vileplume', 5.201827266967495),
#  ('mon_steenee', 5.228508995819073),
#  ('mon_bounsweet', 5.341918457636445),
#  ('mon_gloom', 5.515837626302728),
#  ('mon_necturine', 5.554905652410323)]

# %%
[x for x in m.kv.most_similar('mon_bulbasaur', 100) if x[0].startswith("mon_")]
# Out:
# [('mon_bulbasaur', 0.0),
#  ('mon_lurantistotem', 4.712798368759483),
#  ('mon_lurantis', 4.8749980257024355),
#  ('mon_fomantis', 4.953152018367086),
#  ('mon_steenee', 5.017066729938283)]

# %%
[x for x in m.kv.most_similar('mon_incineroar', 1000) if x[0].startswith("mon_")]
# Out:
# [('mon_torracat', 3.769602462451072),
#  ('mon_litten', 4.022447589715846),
#  ('mon_pokestarwhitedoor', 4.6301716598215155),
#  ('mon_tepig', 4.707009527281012),
#  ('mon_darmanitanzen', 5.1208781162837385),
#  ('mon_darumaka', 5.188067923426434),
#  ('mon_pokestarmonster', 5.267268077778372),
#  ('mon_pignite', 5.27842269566542),
#  ('mon_smokomodo', 5.316435833756997),
#  ('mon_gumshoostotem', 5.518023859791526),
#  ('mon_typenull', 5.595402021149531),
#  ('mon_lycanrocdusk', 5.654033817209377),
#  ('mon_combusken', 5.72976830247726),
#  ('mon_pokestargiant', 5.7689596381318795),
#  ('mon_pokestarblackbelt', 5.784048442682212),
#  ('mon_pikachupopstar', 5.795248865468854),
#  ('mon_raticatealolatotem', 5.8263245417778675),
#  ('mon_melmetal', 5.849351167918341),
#  ('mon_poipole', 5.867865035290514),
#  ('mon_pokestarhumanoid', 5.889360241514911),
#  ('mon_pokestartransport', 5.895422802409413),
#  ('mon_keldeoresolute', 5.916341631754636),
#  ('mon_pikachuphd', 5.920949965449266),
#  ('mon_litleo', 5.922031772480731),
#  ('mon_pikachualola', 5.930533703282457),
#  ('mon_pokestarf002', 5.93170904910514),
#  ('mon_luxio', 5.9417103222879195),
#  ('mon_blacephalon', 5.953909576821206),
#  ('mon_marowakalolatotem', 5.971310977233527),
#  ('mon_pikachuunova', 5.980408407579691),
#  ('mon_ponyta', 5.99237967725974),
#  ('mon_pikachubelle', 6.00034724813083),
#  ('mon_meowthalola', 6.01669834277942),
#  ('mon_kommoototem', 6.017113402674967),
#  ('mon_pikachusinnoh', 6.0216686340965495),
#  ('mon_torchic', 6.022380653148214),
#  ('mon_pokestarblackdoor', 6.078323510685834),
#  ('mon_pichuspikyeared', 6.095204221786473),
#  ('mon_pikachulibre', 6.112054961564026),
#  ('mon_pikachupartner', 6.122987573109959),
#  ('mon_zygardecomplete', 6.135998773541869),
#  ('mon_pikachuoriginal', 6.140884239151553),
#  ('mon_pokestarspirit', 6.147318416767168),
#  ('mon_pikachurockstar', 6.147658738425944),
#  ('mon_shinx', 6.148017613953856),
#  ('mon_pikachuhoenn', 6.169261814023459),
#  ('mon_pikachucosplay', 6.177458102721983),
#  ('mon_pikachukalos', 6.194708393983769),
#  ('mon_salazzletotem', 6.238305252892239),
#  ('mon_emboar', 6.24330605702676),
#  ('mon_zeraora', 6.253995553935172),
#  ('mon_yungoos', 6.274115082738757),
#  ('mon_naganadel', 6.280655887479626),
#  ('mon_rattataalola', 6.282706750653469),
#  ('mon_pokestarmt2', 6.292573713202439),
#  ('mon_pokestarmt', 6.296429431571505),
#  ('mon_salandit', 6.301606225793407),
#  ('mon_pajantom', 6.344337661400106),
#  ('mon_magearnaoriginal', 6.346194521017935),
#  ('mon_eeveestarter', 6.350548427722644),
#  ('mon_meltan', 6.351796919127155),
#  ('mon_grubbin', 6.352572087455891),
#  ('mon_cosmoem', 6.356170596242331),
#  ('mon_cosmog', 6.358467091602209),
#  ('mon_wishiwashischool', 6.362331739598797),
#  ('mon_stakataka', 6.371319341973826),
#  ('mon_lillipup', 6.387323450152381),
#  ('mon_pokestarf00', 6.390388959545865),
#  ('mon_silvallyground', 6.392551655267943),
#  ('mon_pikachustarter', 6.426485626085135),
#  ('mon_cyndaquil', 6.444665193603151),
#  ('mon_mudbray', 6.460118873243842),
#  ('mon_silvallydark', 6.46091816822109),
#  ('mon_herdier', 6.4631867062931345),
#  ('mon_necrozmaultra', 6.4634153764003806),
#  ('mon_lurantistotem', 6.48688182381039),
#  ('mon_flareon', 6.495929140736588),
#  ('mon_crabrawler', 6.495937510633246),
#  ('mon_chimchar', 6.5015727256832845),
#  ('mon_hakamoo', 6.507304199407871),
#  ('mon_necrozmadawnwings', 6.511414103621878),
#  ('mon_vulpixalola', 6.5126298392770865),
#  ('mon_pokestarufo', 6.5281828838666405),
#  ('mon_blaziken', 6.540074664580431),
#  ('mon_marowakalola', 6.541169361131412),
#  ('mon_charjabug', 6.542352716936867),
#  ('mon_miniormeteor', 6.5703095799767235),
#  ('mon_pokestarsmeargle', 6.577206220959806),
#  ('mon_jangmoo', 6.582405102187988),
#  ('mon_silvallyfighting', 6.590111013204836),
#  ('mon_aegislashblade', 6.60201222033413),
#  ('mon_rockruff', 6.610281095781499),
#  ('mon_voodoll', 6.625169753095196),
#  ('mon_unown', 6.6345328399363215),
#  ('mon_scratchet', 6.637864570692559),
#  ('mon_houndour', 6.641169887948966),
#  ('mon_quilava', 6.643423866850888),
#  ('mon_sandshrewalola', 6.654087749518714),
#  ('mon_krokorok', 6.667158928858941),
#  ('mon_pokestarbrycenman', 6.6677791900832055),
#  ('mon_mimikyubustedtotem', 6.6680182760260225),
#  ('mon_fomantis', 6.6720394132143035),
#  ('mon_mimikyubusted', 6.674943499204666),
#  ('mon_castformsnowy', 6.707238679864032),
#  ('mon_togedemarutotem', 6.727197973099922),
#  ('mon_flarelm', 6.727619452148257),
#  ('mon_pikipek', 6.7402206579621415),
#  ('mon_necrozmaduskmane', 6.752002858343149),
#  ('mon_sandile', 6.768471621951171),
#  ('mon_komala', 6.769005315767025),
#  ('mon_mimikyutotem', 6.791168472884475),
#  ('mon_luxray', 6.794407495101454),
#  ('mon_sandygast', 6.794740768313144),
#  ('mon_rebble', 6.799097956099705),
#  ('mon_castform', 6.804936286447659),
#  ('mon_growlithe', 6.807684850654551),
#  ('mon_caribolt', 6.808492453797551),
#  ('mon_stufful', 6.809870093117523),
#  ('mon_ditto', 6.817799632274728),
#  ('mon_pokestarufopropu2', 6.823943158670121),
#  ('mon_pokestarufo2', 6.849830425359544),
#  ('mon_buzzwole', 6.855297962682925),
#  ('mon_grimeralola', 6.862778438461602),
#  ('mon_trumbeak', 6.864220432347172),
#  ('mon_rapidash', 6.866138399866868),
#  ('mon_silvallysteel', 6.8689853672381735),
#  ('mon_arcanine', 6.869370164797187),
#  ('mon_lycanroc', 6.877787284983547),
#  ('mon_guzzlord', 6.879433081919014),
#  ('mon_poochyena', 6.883126068892078),
#  ('mon_popplio', 6.892636769109545),
#  ('mon_silvally', 6.89396003090115),
#  ('mon_silvallyfire', 6.8949461328140185),
#  ('mon_stoutland', 6.898474722176559),
#  ('mon_breezi', 6.900208257873879),
#  ('mon_zorua', 6.901643753114068),
#  ('mon_vivillonpokeball', 6.911096315133401),
#  ('mon_magmar', 6.913787097097565),
#  ('mon_wimpod', 6.913870840881354),
#  ('mon_passimian', 6.923331360566805),
#  ('mon_vikavolttotem', 6.936873317127823),
#  ('mon_magby', 6.937875736008975),
#  ('mon_cawdet', 6.942333905164836),
#  ('mon_larvesta', 6.973828287240885),
#  ('mon_gumshoos', 6.974082746675404),
#  ('mon_volkritter', 6.976702350869081),
#  ('mon_darmanitan', 6.986947824096214),
#  ('mon_mightyena', 6.99953292709265),
#  ('mon_brionne', 7.001158439929835),
#  ('mon_steenee', 7.005822410280548),
#  ('mon_blazikenmega', 7.010339801667757),
#  ('mon_deino', 7.011584224839872),
#  ('mon_ursaring', 7.021059293000385),
#  ('mon_zweilous', 7.028814959418252),
#  ('mon_tactite', 7.03352473862373),
#  ('mon_graveleralola', 7.03521449119191),
#  ('mon_monferno', 7.03986797663317),
#  ('mon_blitzle', 7.043474358053093),
#  ('mon_vivillonfancy', 7.04967444287547),
#  ('mon_salazzle', 7.059860838760065),
#  ('mon_diglettalola', 7.060460056517548),
#  ('mon_mareanie', 7.063817336955813),
#  ('mon_missingno', 7.083433402767342),
#  ('mon_silvallyflying', 7.086603230756643),
#  ('mon_dartrix', 7.088004066703715),
#  ('mon_rowlet', 7.091129619201659),
#  ('mon_geodudealola', 7.097108602877815),
#  ('mon_silvallydragon', 7.098148191757506),
#  ('mon_silvallygrass', 7.10447118902431),
#  ('mon_privatyke', 7.106825954452447),
#  ('mon_bagon', 7.110080256162352),
#  ('mon_crabominable', 7.11080607102687),
#  ('mon_pawniard', 7.121330122516745),
#  ('mon_snugglow', 7.125737934037883),
#  ('mon_silvallywater', 7.127303135614943),
#  ('mon_silvallyice', 7.1310868335965685),
#  ('mon_absolmega', 7.138233964913243),
#  ('mon_snubbull', 7.146548960802588),
#  ('mon_floatoy', 7.1517117732428455),
#  ('mon_colossoil', 7.153901456664093),
#  ('mon_raticatealola', 7.158603384043001),
#  ('mon_necturine', 7.159368318409545),
#  ('mon_silvallypoison', 7.1632308585653215),
#  ('mon_trapinch', 7.163446962976296),
#  ('mon_entei', 7.165856122693008),
#  ('mon_marshadow', 7.172290738837438),
#  ('mon_raticate', 7.194059791748596),
#  ('mon_kartana', 7.197220868962801),
#  ('mon_silvallyfairy', 7.207660527194674),
#  ('mon_slakoth', 7.209396863053097),
#  ('mon_metapod', 7.214204031471307),
#  ('mon_teddiursa', 7.21953873913001),
#  ('mon_shelgon', 7.236323956920439),
#  ('mon_ribombeetotem', 7.240529101017312),
#  ('mon_taillow', 7.245696638845509),
#  ('mon_silvallyrock', 7.245733193980198),
#  ('mon_snaelstrom', 7.251547399014167),
#  ('mon_araquanidtotem', 7.255301066581236),
#  ('mon_silvallyelectric', 7.260431113288477),
#  ('mon_argalis', 7.26888064006844),
#  ('mon_solgaleo', 7.275791042487117),
#  ('mon_pansear', 7.282306182546444),
#  ('mon_turtonator', 7.284991544045081),
#  ('mon_bounsweet', 7.292231825262903),
#  ('mon_dewpider', 7.29960362135699),
#  ('mon_cupra', 7.307256131664681),
#  ('mon_stunky', 7.30744503271383),
#  ('mon_heatmor', 7.308957135572421),
#  ('mon_loudred', 7.3104877529559085),
#  ('mon_caimanoe', 7.311430140840187),
#  ('mon_whismur', 7.31797947926458),
#  ('mon_oricorio', 7.319122484635221),
#  ('mon_silcoon', 7.322058288781176),
#  ('mon_vibrava', 7.322408227354287),
#  ('mon_riolu', 7.326388269597767),
#  ('mon_embirch', 7.326400884749619),
#  ('mon_minccino', 7.328652130848741),
#  ('mon_charmander', 7.333679648815175),
#  ('mon_kommoo', 7.335568867381984),
#  ('mon_cubchoo', 7.343174376168531),
#  ('mon_klink', 7.34436977375358),
#  ('mon_celesteela', 7.344478907266487),
#  ('mon_mumbao', 7.347352156561146),
#  ('mon_silvallyghost', 7.3564804845194995),
#  ('mon_pheromosa', 7.358807588864488),
#  ('mon_timburr', 7.360002871083344),
#  ('mon_silvallybug', 7.360366543493193),
#  ('mon_pupitar', 7.361849353710393),
#  ('mon_starly', 7.363944957096616),
#  ('mon_klang', 7.3653002618002485),
#  ('mon_brattler', 7.367835404454722),
#  ('mon_zangoose', 7.3766583971991695),
#  ('mon_gurdurr', 7.378355873444023),
#  ('mon_sharpedomega', 7.385549695019037),
#  ('mon_patrat', 7.390342675813925),
#  ('mon_burmy', 7.393988814340147),
#  ('mon_zigzagoon', 7.399281557177656),
#  ('mon_larvitar', 7.3994528973140685),
#  ('mon_zygarde10', 7.411231049403461),
#  ('mon_cameruptmega', 7.41195341854739),
#  ('mon_dragonair', 7.412682983715039),
#  ('mon_persianalola', 7.415095108757066),
#  ('mon_silvallypsychic', 7.415383942125487),
#  ('mon_syclar', 7.419184338226688),
#  ('mon_rattata', 7.420595082278427),
#  ('mon_fraxure', 7.422020270224347),
#  ('mon_skuntank', 7.4255819154351155),
#  ('mon_mimikyu', 7.430509098611068),
#  ('mon_gabite', 7.434666841366371),
#  ('mon_vigoroth', 7.440177987542076),
#  ('mon_sentret', 7.441762000983493),
#  ('mon_cascoon', 7.442608843052791),
#  ('mon_cranidos', 7.444280116932731),
#  ('mon_kakuna', 7.446298612985068),
#  ('mon_fletchinder', 7.446344488092662),
#  ('mon_fletchling', 7.449917368930791),
#  ('mon_typhlosion', 7.450681675364533),
#  ('mon_tynamo', 7.454102079339251),
#  ('mon_minior', 7.455127398357034),
#  ('mon_mewtwomegax', 7.45595688250641),
#  ('mon_shedinja', 7.45595773068657),
#  ('mon_charizardmegax', 7.456662367155016),
#  ('mon_staravia', 7.458043930504474),
#  ('mon_toucannon', 7.463397096441961),
#  ('mon_absol', 7.46796288107519),
#  ('mon_nincada', 7.470096798902512),
#  ('mon_houndoom', 7.473849603969845),
#  ('mon_bewear', 7.473963330802997),
#  ('mon_wurmple', 7.477855250987454),
#  ('mon_nidoranf', 7.478308627123625),
#  ('mon_krookodile', 7.481310629787533),
#  ('mon_pancham', 7.481956883167819),
#  ('mon_sneasel', 7.482879398051377),
#  ('mon_voodoom', 7.484814451010035),
#  ('mon_magikarp', 7.487528954665013),
#  ('mon_axew', 7.489062707498075),
#  ('mon_dugtrioalola', 7.489357406788759),
#  ('mon_dewott', 7.491188756981196),
#  ('mon_charmeleon', 7.4911953343162105),
#  ('mon_archen', 7.492682854579697),
#  ('mon_pyroak', 7.506976158843798),
#  ('mon_gible', 7.518556014409705),
#  ('mon_dratini', 7.5197526935416175),
#  ('mon_necrozma', 7.521633967969035),
#  ('mon_oshawott', 7.523218324790921),
#  ('mon_nidorino', 7.528182764275074),
#  ('mon_phanpy', 7.528668237241321),
#  ('mon_slaking', 7.530637965335044),
#  ('mon_oricoriopompom', 7.531031952081342),
#  ('mon_rayquazamega', 7.531083031555543),
#  ('mon_crucibellemega', 7.533944423410456),
#  ('mon_croconaw', 7.535024129061182),
#  ('mon_linoone', 7.538470509312762),
#  ('mon_buneary', 7.53997230335496),
#  ('mon_sandslashalola', 7.541510792725843),
#  ('mon_jumbao', 7.543340707727157),
#  ('mon_kricketot', 7.543560927876441),
#  ('mon_mukalola', 7.5467131749635765),
#  ('mon_croagunk', 7.547318617431872),
#  ('mon_castformsunny', 7.548340332650737),
#  ('mon_oricoriosensu', 7.551428800059517),
#  ('mon_purrloin', 7.55213529473498),
#  ('mon_skiddo', 7.554868604792925),
#  ('mon_tapukoko', 7.555766488514115),
#  ('mon_eelektrik', 7.557546174021248),
#  ('mon_naviathan', 7.561647750107148),
#  ('mon_morelull', 7.563581057338743),
#  ('mon_meloettapirouette', 7.563776313634193),
#  ('mon_pluffle', 7.566969664324222),
#  ('mon_electrike', 7.567577140958359),
#  ('mon_cutiefly', 7.5676873798811854),
#  ('mon_weedle', 7.57352423616593),
#  ('mon_bunnelby', 7.5763488428113765),
#  ('mon_swinub', 7.576463898531102),
#  ('mon_makuhita', 7.581106778164125),
#  ('mon_honedge', 7.582392110977741),
#  ('mon_mudsdale', 7.592789645784951),
#  ('mon_lurantis', 7.593417744281031),
#  ('mon_bisharp', 7.599602284745571),
#  ('mon_arceus', 7.600665257092668),
#  ('mon_inkay', 7.604305667827368),
#  ('mon_scraggy', 7.60644153513402),
#  ('mon_hippopotas', 7.609268131471904),
#  ('mon_houndoommega', 7.615146261757721),
#  ('mon_oricoriopau', 7.616558320959908),
#  ('mon_aipom', 7.62371757995376),
#  ('mon_cacnea', 7.627405061107279),
#  ('mon_stantler', 7.628949127423164),
#  ('mon_karrablast', 7.630892470593142),
#  ('mon_caterpie', 7.634214895427474),
#  ('mon_arceusrock', 7.635318708594056),
#  ('mon_piloswine', 7.638776192004178),
#  ('mon_glameow', 7.639419516447634),
#  ('mon_rufflet', 7.6436194908741895),
#  ('mon_braixen', 7.643874147209073),
#  ('mon_mienfoo', 7.644892137040923),
#  ('mon_wishiwashi', 7.645135000982374),
#  ('mon_nidoking', 7.64615997865903),
#  ('mon_cobalion', 7.6466798861094185),
#  ('mon_lycanrocmidnight', 7.647485140318842),
#  ('mon_decidueye', 7.655384448750294),
#  ('mon_lairon', 7.663987238940053),
#  ('mon_fennekin', 7.666627575920748),
#  ('mon_bidoof', 7.670507753667911),
#  ('mon_tyrunt', 7.674129735730103),
#  ('mon_helioptile', 7.6815796156474985),
#  ('mon_slugma', 7.68616149106131),
#  ('mon_golett', 7.687313948766595)]

# %%
mon_vecs = [m.kv.get_vector(x) for x in m.kv.vocab if x.startswith('mon_')]

# %%
mon_vecs_df = pd.DataFrame(mon_vecs, index=[x for x in m.kv.vocab if x.startswith('mon_')])

# %%
mon_vecs_df.to_csv("20191005_mon_vecs_type-egg-ability-moves.txt", sep="\t")

# %%
tuples_df = pd.DataFrame(tuples)

# %%
tuples_df.columns = ['mon_str', 'feature_category']

# %%
tuples_df.tail()
# Out:
#            mon_str     feature_category
# 15740  mon_voodoom           move_taunt
# 15741  mon_voodoom       move_painsplit
# 15742  mon_voodoom      move_substitute
# 15743  mon_voodoom  move_hiddenpowerice
# 15744  mon_voodoom      move_vacuumwave

# %%
tuples_df['mon'] = tuples_df['mon_str'].apply(lambda x: x.split("mon_")[1])

# %%
tuples_df['feature'] = tuples_df['feature_category'].apply(lambda x: x.split("_")[0])

# %%
tuples_df.head()
# Out:
#          mon_str       feature_category        mon    feature
# 0  mon_bulbasaur            types_Grass  bulbasaur      types
# 1  mon_bulbasaur           types_Poison  bulbasaur      types
# 2  mon_bulbasaur     abilities_Overgrow  bulbasaur  abilities
# 3  mon_bulbasaur  abilities_Chlorophyll  bulbasaur  abilities
# 4  mon_bulbasaur      eggGroups_Monster  bulbasaur  eggGroups

# %%
tuples_df['feature_val'] = tuples_df['feature_category'].apply(lambda x: x.split("_")[1])

# %%
tuples_df[['mon', 'feature', 'feature_val']].to_csv("./20191005_mon_types-abilities-egg-moves_features.tsv", sep="\t", index=None)

# %%
tuples_df.head()
# Out:
#          mon_str       feature_category        mon    feature  feature_val
# 0  mon_bulbasaur            types_Grass  bulbasaur      types        Grass
# 1  mon_bulbasaur           types_Poison  bulbasaur      types       Poison
# 2  mon_bulbasaur     abilities_Overgrow  bulbasaur  abilities     Overgrow
# 3  mon_bulbasaur  abilities_Chlorophyll  bulbasaur  abilities  Chlorophyll
# 4  mon_bulbasaur      eggGroups_Monster  bulbasaur  eggGroups      Monster

# %%
m.save("./20191005_poincare_embeddings_model_w_features_n_moves.model")
